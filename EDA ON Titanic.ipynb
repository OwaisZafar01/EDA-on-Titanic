# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### **Dataset Column Types**
#
# #### **1️⃣ Numerical Columns**
# - `PassengerId`
# - `Age`
# - `Fare`
#
# #### **2️⃣ Categorical Columns**
# - `Survived`
# - `Pclass`
# - `Sex`
# - `SibSp`
# - `Parch`
# - `Embarked`
#
# #### **3️⃣ Mixed / String Columns**
# - `Ticket`
# - `Cabin`
# - `Name`

# %% [markdown]
# ## **📊 Univariate Analysis**
#
# Univariate analysis focuses on **understanding the distribution of a single variable**.
# It helps to identify:
# - How the data is **spread**
# - Presence of **outliers**
# - **Most frequent values**
#
# ---
#
# ### **1️⃣ Numerical Columns**
# - Visualized using **Histogram**, **KDE Plot**, and **Box Plot**
# - Example columns: `Age`, `Fare`
#
# **Key insights to observe:**
# 1. Mean, Median, and Standard Deviation
# 2. Skewness (Left or Right)
# 3. Presence of outliers
#
# ---
#
# ### **2️⃣ Categorical Columns**
# - Visualized using **Countplot**, **Bar Chart**, and **Pie Chart**
# - Example columns: `Sex`, `Pclass`, `Embarked`
#
# **Key insights to observe:**
# 1. Most frequent categories
# 2. Rare categories
# 3. Class imbalance (if any)
#
# ---
#
# ### **3️⃣ Mixed / String Columns**
# - Columns like `Name`, `Ticket`, `Cabin`
# - Mostly analyzed through **counts or unique values**
# - Detailed statistical visualization is usually not meaningful
#
# ---
#
# **Next Step:**
# - Plot each column to **visualize its distribution** and note **important insights**.

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(8,5))  
sns.histplot(df['Age'], bins=5, color='skyblue', edgecolor='black')  

plt.title("Age Distribution", fontsize=16, fontweight='bold')  
plt.xlabel("Age", fontsize=12)  
plt.ylabel("Frequency", fontsize=12)  
plt.grid(axis='y', linestyle='--', alpha=0.7) 
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Age'], 
            color='blue', 
            fill=True,       
            alpha=0.3,       
            linewidth=2)     

plt.title("Age Distribution", fontsize=16, fontweight='bold')
plt.xlabel("Age", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.set_style("whitegrid")  
sns.boxplot(x=df['Age'], 
            color='lightgreen', 
            width=0.5,        
            linewidth=2,      
            fliersize=6)      

plt.title("Age Distribution", fontsize=16, fontweight='bold')
plt.xlabel("Age", fontsize=12)

plt.show()

# %%
df[df['Age']>64]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
missing_values_in_age_column = df['Age'].isnull().sum()/df.shape[0] * 100
print(missing_values_in_age_column)
# Out:
# 19.865319865319865

# %% [markdown]
# ### **Observation**
#
#
# - Around **19.87%** of the values are missing.
# - A few **outliers** are present at higher ages.
# - The distribution is **approximately normal**, not strongly left or right‑skewed.
# - Most passengers fall in the **20–30 age range**.

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
plt.figure(figsize=(8,5))  
sns.histplot(df['Fare'], bins=5, color='salmon', edgecolor='black')  

plt.title("Fare Distribution", fontsize=16, fontweight='bold')  
plt.xlabel("Fare", fontsize=12)  
plt.ylabel("Frequency", fontsize=12)  
plt.grid(axis='y', linestyle='--', alpha=0.7)  
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Fare'], 
            color='#20B2AA', 
            fill=True,       
            alpha=0.3,       
            linewidth=2)     

plt.title("Fare Distribution", fontsize=16, fontweight='bold')
plt.xlabel("Fare", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.set_style("whitegrid")  
sns.boxplot(x=df['Fare'], 
            color='#DC143C', 
            width=0.5,        
            linewidth=2,      
            fliersize=6)      

plt.title("Fare Distribution", fontsize=16, fontweight='bold')
plt.xlabel("Fare", fontsize=12)

plt.show()

# %%
df[df['Fare']>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
missing_values_in_fare_column = df['Fare'].isnull().sum()
print(missing_values_in_fare_column)
# Out:
# 0

# %% [markdown]
# ### **Observation**
#
# - No **missing values** are present in this column.
# - The distribution is **highly positively skewed**, with most passengers paying lower fares and a few paying very high fares.
# - The column seems to **represent group fares rather than individual fares**, which may lead to misleading insights.
# - A new column for **individual fare** should be created by dividing the total fare by the number of passengers in the booking.

# %%
dist = df['Survived'].value_counts()
dist
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
ax = dist.plot(kind='bar', color=['#9370DB','#FFC107'], edgecolor='black')

for i, value in enumerate(dist):
    plt.text(i, value + 5, str(value), ha='center', fontsize=11, fontweight='semibold')

custom_labels = ['0 → Died', '1 → Survived']
handles = [plt.Rectangle((0,0),1,1,color=c) for c in ['#9370DB','#FFC107']]
plt.legend(handles, custom_labels, title='Status')

plt.title('Survived', fontsize=14, fontweight='bold', color='#333333')
plt.xlabel('Survived', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.xticks(rotation=0)
plt.show()

# %%
colors = ['#DC143C','#32CD32'] 

plt.figure(figsize=(7,7))

wedges, texts, autotexts = plt.pie(
    dist.values,
    labels=['Died','Survived'],
    autopct='%1.1f%%',
    colors=colors,
    startangle=90,
    explode=[0.03,0.0],
    wedgeprops={'edgecolor':'black'},
    textprops={'fontsize':11, 'color':'black'}
)

plt.title('Survived', fontsize=16, fontweight='bold')
plt.show()

# %%
missing_values_in_Survived_column = df['Survived'].isnull().sum()
print(missing_values_in_Survived_column)
# Out:
# 0

# %% [markdown]
# ### **Observation**
#
# - **No missing values** are present in this column.
# - Out of **891 passengers**, **549 (61.7%) died** and **342 (38.3%) survived**.
# - There is a **class imbalance**, with more passengers in the **died** compared to the **survived**.
# - Visualizations clearly highlight the **majority of passengers did not survive**.

# %%
dist = df['Pclass'].value_counts()
dist
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

ax = sns.countplot(
    x=df['Pclass'], 
    hue=df['Pclass'], 
    palette=['#1ABC9C','#E67E22','#9B59B6'],  
    dodge=False, 
    legend=False
)

for container in ax.containers:
    ax.bar_label(container, fmt='%d', fontsize=12, fontweight='bold')

custom_labels = ['1 → 1st Class', '2 → 2nd Class', '3 → 3rd Class']
handles = [plt.Rectangle((0,0),1,1,color=c) 
           for c in ['#1ABC9C','#E67E22','#9B59B6']]
plt.legend(handles, custom_labels, title='Passenger Class')

plt.title('Passenger Class', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Pclass', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(7,5))
bars = plt.bar(dist.index.astype(str), dist.values,
               color=['#1ABC9C','#E67E22','#9B59B6'], edgecolor='black', width=0.6)

for i, value in enumerate(dist.values):
    plt.text(i, value+5, str(value), ha='center', fontsize=11, fontweight='bold')

custom_labels = ['1 → 1st Class', '2 → 2nd Class', '3 → 3rd Class']
handles = [plt.Rectangle((0,0),1,1,color=c) 
           for c in ['#1ABC9C','#E67E22','#9B59B6']]
plt.legend(handles, custom_labels, title='Passenger Class')

plt.title('Passenger Class', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Pclass', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,7))
colors = ['#1E90FF', '#32CD32', '#FFD700']

wedges, texts, autotexts = ax.pie(
    dist.values,
    labels=None, 
    autopct='%1.1f%%',
    pctdistance=0.75,         
    colors=colors,
    startangle=90,
    wedgeprops={'edgecolor':'black'},
    textprops={'fontsize':12, 'fontweight':'bold', 'color':'white'} 
)

centre_circle = plt.Circle((0,0), 0.55, fc='white')
fig.gca().add_artist(centre_circle)

custom_labels = ['1 → 1st Class', '2 → 2nd Class', '3 → 3rd Class']
handles = [plt.Rectangle((0,0),1,1,color=c) for c in colors]
plt.legend(handles, custom_labels, title='Passenger Class', loc='upper right')

plt.title('Passenger Class', fontsize=18, fontweight='bold', color='#333333')
plt.show()

# %% [markdown]
# ### **Observation**
#
# - **No missing values** are present in this column.
# - Out of **891 passengers**, **3rd class has 491 (55.1%)**, **1st class 216 (24.2%)**, and **2nd class 184 (20.7%)**.
# - There is a **class imbalance**, with **most passengers in 3rd class**, and **2nd class has fewer passengers than 1st class**, which is a bit unusual.

# %%
dist = df['Sex'].value_counts()
dist
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
ax = dist.plot(kind='bar', color=['#1E90FF','#FF69B4'], edgecolor='black')

for i, value in enumerate(dist):
    plt.text(i, value + 5, str(value), ha='center', fontsize=11, fontweight='semibold')

plt.title('Passenger Sex Distribution', fontsize=14, fontweight='bold', color='#333333')
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.xticks(rotation=0)

plt.show()

# %%
colors = ['#20B2AA','#FFD700']  

plt.figure(figsize=(7,7))

wedges, texts, autotexts = plt.pie(
    dist.values,
    labels=['Male','Female'],        
    autopct='%1.1f%%',               
    colors=colors,
    startangle=90,
    explode=[0.03, 0.0],           
    wedgeprops={'edgecolor':'black'},
    textprops={'fontsize':11, 'color':'black'}  
)
plt.title('Passenger Sex Distribution', fontsize=16, fontweight='bold')
plt.show()

# %%
missing_values_in_sex_column = df['Sex'].isnull().sum()
print(missing_values_in_sex_column)
# Out:
# 0

# %% [markdown]
# ### **Observation**
#
# - **No missing values** are present in this column.
# - Out of **891 passengers**, **male passengers are 577 (64.8%)** and **female passengers are 314 (35.2%)**.
# - There is a **class imbalance**, with **more male passengers than female passengers**.

# %%
dist = df['SibSp'].value_counts().sort_index()
dist
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 3     16
# 4     18
# 5      5
# 8      7
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
ax = dist.plot(
    kind='bar', 
    color=['#20B2AA','#FF7F50','#9370DB','#FFD700','#DC143C','#8A2BE2','#3CB371'], 
    edgecolor='black'
)

for i, value in enumerate(dist):
    plt.text(i, value + 2, str(value), ha='center', fontsize=11, fontweight='semibold')

plt.title('Number of Siblings/Spouses Aboard (SibSp)', fontsize=14, fontweight='bold', color='#333333')
plt.xlabel('SibSp', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.xticks(rotation=0)
plt.show()

# %%
missing_values_in_SibSp_column = df['SibSp'].isnull().sum()
print(missing_values_in_SibSp_column)
# Out:
# 0

# %% [markdown]
# ### **Observation**
#
# - **No missing values** are present in this column.
# - Most passengers (**608 → 68.3%**) were **traveling alone** with no siblings or spouses.
# - **209 passengers (23.5%)** had **only 1 sibling or spouse** aboard.
# - Very **few passengers traveled with 2 or more family members**, showing that large family groups were uncommon.

# %%
dist = df['Parch'].value_counts().sort_index()
dist
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 3      5
# 4      4
# 5      5
# 6      1
# Name: count, dtype: int64

# %%
colors = ['#1E90FF','#32CD32','#FFD700','#FF7F50','#9370DB','#DC143C','#8A2BE2']

plt.figure(figsize=(8,5))
ax = dist.plot(kind='bar', color=colors[:len(dist)], edgecolor='black')

for i, value in enumerate(dist):
    plt.text(i, value + 3, str(value), ha='center', fontsize=11, fontweight='semibold')

plt.title('Passenger Parch Distribution', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Parch (Parents/Children Aboard)', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.show()

# %%
missing_values_in_Parch_column = df['Parch'].isnull().sum()
print(missing_values_in_Parch_column)
# Out:
# 0

# %% [markdown]
# ### **Observation**
#
# - **No missing values** are present in this column.
# - Majority of passengers (**678 → 76.1%**) **did not have parents or children aboard**.
# - **118 passengers (13.2%)** had **1 parent/child**, and **80 passengers (9%)** had **2 parents/children**.
# - Very **few passengers traveled with 3 or more parents/children**, showing that large family groups were uncommon.

# %% [markdown]
# ### **Additional Observation – Family Members**
#
# - The `SibSp` column (siblings/spouses) and the `Parch` column (parents/children)
#   **together represent the total family members traveling with a passenger**.
# - Technically, these can be **combined into a single feature**, such as
#   **`FamilySize = SibSp + Parch`**, which gives the **total family size** aboard.
# - A **new column can also indicate whether the passenger was traveling alone**,
#   since the majority of passengers had **no family members** aboard.
# - These engineered features can be **useful in survival analysis**,
#   as traveling alone vs. with family may influence survival chances.

# %%
dist = df['Embarked'].value_counts()
dist
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
colors = ['#1E90FF','#32CD32','#FFD700']  

plt.figure(figsize=(8,5))
ax = dist.plot(kind='bar', color=colors, edgecolor='black')

for i, value in enumerate(dist):
    plt.text(i, value + 5, str(value), ha='center', fontsize=11, fontweight='semibold')

plt.xticks(
    ticks=range(len(dist)),
    labels=['Southampton', 'Cherbourg', 'Queenstown'],
    rotation=0,
    fontsize=11
)
plt.title('Passenger Embarkation Distribution', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Embarked Port', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,7))
colors = ['#1E90FF','#32CD32','#FFD700']  

wedges, texts, autotexts = ax.pie(
    dist.values,
    labels=None,
    autopct='%1.1f%%',
    pctdistance=0.75,
    colors=colors,
    startangle=90,
    wedgeprops={'edgecolor':'black'},
    textprops={'fontsize':11, 'color':'black'}
)

centre_circle = plt.Circle((0,0), 0.55, fc='white')
fig.gca().add_artist(centre_circle)

custom_labels = ['S → Southampton', 'C → Cherbourg', 'Q → Queenstown']
handles = [plt.Rectangle((0,0),1,1,color=c) for c in colors]
plt.legend(handles, custom_labels, title='Embarkation Port', loc='upper right')
plt.title('Passenger Embarkation', fontsize=16, fontweight='bold', color='#333333')
plt.show()

# %%
missing_values_in_Embarked_column = df['Embarked'].isnull().sum()
print(missing_values_in_Embarked_column)
# Out:
# 2

# %% [markdown]
# ### **Observation**
#
# - **Missing Values:** 2 entries are missing.
# - **Southampton (S):** 644 passengers (**72.3%**)
# - **Cherbourg (C):** 168 passengers (**18.9%**)
# - **Queenstown (Q):** 77 passengers (**8.6%**)
# - **Insight:** The column shows a **clear imbalance**, as most passengers **started their journey from Southampton**.

# %% [markdown]
# ## **📊 Bivariate Analysis**
#
# Bivariate analysis means studying the **relationship between two columns** in a dataset.
# It helps us understand:
# - How one column affects or relates to another
# - Patterns or trends between the two columns
# - Any unusual points or imbalances
#
# ---
#
# ### **1️⃣ Numerical ↔ Numerical**
# - Both columns are **numbers**
# - Use **Scatter Plot**, **2D Histogram**, or **2D KDE Plot** to see the relationship
# - Can also check **correlation** to see if they increase or decrease together
#
# **Things to look for:**
# 1. Are the numbers **moving together** (positive or negative relationship)?
# 2. Any **clusters or patterns**?
# 3. Any **outliers** that don’t follow the trend?
#
# ---
#
# ### **2️⃣ Numerical ↔ Categorical**
# - One column is **number** and the other is **category**
# - Use **Box Plot**, **Violin Plot**, **Bar Plot** to compare
#
# **Things to look for:**
# 1. Which category has **higher or lower numbers**
# 2. **Spread of data** in each category
# 3. If there are **outliers** in some categories
#
# ---
#
# ### **3️⃣ Categorical ↔ Categorical**
# - Both columns are **categories**
# - Use **Count Plot**, **Stacked Bar Plot**, or **Heatmap**
#
# **Things to look for:**
# 1. Which combination appears **most often**
# 2. Any **imbalance** in the counts
# 3. Very **rare combinations** of categories
#
# ---
#
# **Next Step:**
# - Pick any two columns, make a chart, and see **how they are related**.
# - Write down **your observations** clearly.

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
crosstab = pd.crosstab(df['Survived'], df['Pclass'], normalize='columns') * 100
crosstab
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
plt.figure(figsize=(8,6))
sns.set_style("white")

sns.heatmap(crosstab, 
            annot=True, 
            fmt='.1f', 
            cmap='viridis',     
            cbar_kws={'label': 'Percentage %'}, 
            linewidths=1.5, 
            linecolor='white', 
            annot_kws={"size":12, "weight":"bold", "color":"black"}, 
            square=True)            

plt.title('Survival Rate by Passenger Class', fontsize=16, fontweight='bold', color='#333333', pad=15)
plt.xlabel('Passenger Class', fontsize=13)
plt.ylabel('Survived (0 = Died, 1 = Survived)', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11, rotation=0)

plt.show()

# %% [markdown]
# ### **Observation – Survival Rate by Passenger Class**
#
# - *Traveling in **3rd Class (Pclass 3)** was the riskiest,* with **~75.8% passengers dying**.
# - *Traveling in **1st Class (Pclass 1)** was the safest,*  with a **~63% survival rate**.
# - *2nd Class (Pclass 2) had moderate risk,*  with **~52.7% passengers dying**.
# - **Overall Trend:**
#   *Survival chances clearly decrease as the class number increases →*
#   **Pclass 1 > Pclass 2 > Pclass 3**.

# %%
crosstab = pd.crosstab(df['Survived'], df['Sex'], normalize='columns') * 100
crosstab
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
plt.figure(figsize=(6,4))
sns.heatmap(
    crosstab, 
    annot=True,         
    fmt='.1f',          
    cmap='PiYG',      
    cbar_kws={'label':'Percentage %'}, 
    linewidths=0.5, 
    linecolor='white'
)

plt.title('Survival Rate by Sex', fontsize=14, fontweight='bold', color='#333333')
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Survived (0 = Died, 1 = Survived)', fontsize=12)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ### **Observation – Survival Rate by Sex**
# - **Female** was the safest, with a **high survival rate (~74%)**.
# - **Male** was highly risky, with a **low survival rate (~19%)**.
# - **Overall Trend:**
#   *Females had a much higher chance of survival than males →*
#   **Female > Male**

# %%
crosstab = pd.crosstab(df['Survived'], df['Embarked'], normalize='columns') * 100
crosstab
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
plt.figure(figsize=(7,4))
sns.heatmap(
    crosstab, 
    annot=True,         
    fmt='.1f',           
    cmap='cividis',       
    cbar_kws={'label':'Percentage %'},
    linewidths=0.5,
    linecolor='white'
)

plt.title('Survival Rate by Embarked Port', fontsize=14, fontweight='bold', color='#333333')
plt.xlabel('Embarked Port', fontsize=12)
plt.ylabel('Survived (0 = Died, 1 = Survived)', fontsize=12)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ### **Observation – Survival Rate by Embarked**
#
# - *Passengers from **Cherbourg (C)** were the safest,* with **~55% survival rate**.
# - *Passengers from **Queenstown (Q)** had moderate survival,* with **~39% survival rate**.
# - *Passengers from **Southampton (S)** were the riskiest,* with **~34% survival rate**.
# - **Possible Reason:**
#   *Higher survival in **C** may be due to*
#   1. **More female passengers boarding at Cherbourg**
#   2. **More 1st-class passengers from Cherbourg**, who had better survival chances
# - **Overall Trend:**
#   *Survival chances vary by boarding port →*
#   **C > Q > S**

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(df[df['Survived']==0]['Age'], 
            fill=True, 
            color='#DC143C', 
            alpha=0.3, 
            linewidth=2, 
            label='Died (0)')

sns.kdeplot(df[df['Survived']==1]['Age'], 
            fill=True, 
            color='#32CD32', 
            alpha=0.3, 
            linewidth=2, 
            label='Survived (1)')

plt.title('Survival Distribution by Age', fontsize=16, fontweight='bold')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df1 = pd.read_csv('test.csv')
df1.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df = pd.concat([df, df1])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 360         1252       NaN       3        Sage, Master. William Henry    male
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df['Individual_Fare'] = df['Fare'] / (df['SibSp']+df['Parch'] + 1)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df['Family_size'] = df['SibSp'] + df['Parch'] + 1
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
# family type

def transform_family_size(num):
    if num == 1:
        return 'Alone'

    elif num > 1 and num < 5:
        return 'Small'

    else:
        return 'Large'

# %%
df['Family_Type'] = df['Family_size'].apply(transform_family_size)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
crosstab = pd.crosstab(df['Survived'], df['Family_Type'], normalize='columns')*100
crosstab
# Out:
# Family_Type      Alone      Large      Small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
plt.figure(figsize=(7,5))
sns.heatmap(crosstab, 
            annot=True,             
            fmt='.1f',              
            cmap='viridis',       
            cbar_kws={'label': 'Percentage %'}, 
            linewidths=0.5, 
            linecolor='white')

plt.title('Survival Rate by Family Type', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Family Type', fontsize=12)
plt.ylabel('Survived (0 = Died, 1 = Survived)', fontsize=12)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### **Observation – Survival Rate by Family Type**
#
# - *Passengers traveling with **small families** had the **highest survival chance (~57.9%)***.
# - *Passengers traveling **alone** had a **much lower survival rate (~30.3%)***.
# - *Passengers with **large families** were the **riskiest (~16.1% survival rate)***.
# - **Overall Trend:**
#   *Survival chances decrease as family size increases →*
#   **Small > Alone > Large**

# %%
# Extracting Surname
df['SirName'] = df['Name'].str.split(',').str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
# Extractin Title

df['Title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Mlle.          2
# Major.         2
# Ms.            2
# Lady.          1
# Sir.           1
# Mme.           1
# Don.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: count, dtype: int64

# %%
df['Title'] = df['Title'].str.replace(
    r'(Rev\.|Dr\.|Col\.|Don\.|Capt\.|the|Jonkheer\.|Major\.)', 
    'Others', 
    regex=True
)

# %%
df['Title'] = df['Title'].replace({
    'Ms.':'Mrs.',
    'Mlle.':'Mrs.',
    'Dona.':'Mrs.',
    'Mme.':'Mrs.',
    'Lady.':'Mrs.'
})

# %%
df['Title'] = df['Title'].replace({'Sir.':'Mr.'})

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.        758
# Miss.      260
# Mrs.       204
# Master.     61
# Others      26
# Name: count, dtype: int64

# %%
crosstab = pd.crosstab(df['Survived'], df['Title'], normalize='columns') * 100
crosstab
# Out:
# Title     Master.     Miss.        Mr.  Mrs.     Others
# Survived
# 0.0          42.5  30.21978  84.169884  20.0  71.428571
# 1.0          57.5  69.78022  15.830116  80.0  28.571429

# %%
plt.figure(figsize=(8,5))
sns.heatmap(crosstab, 
            annot=True,        
            fmt='.1f',         
            cmap='YlGnBu',     
            linewidths=0.5, 
            linecolor='white', 
            cbar_kws={'label':'Percentage %'})

plt.title('Survival Rate by Passenger Title', fontsize=14, fontweight='bold')
plt.xlabel('Passenger Title', fontsize=12)
plt.ylabel('Survived (0 = Died, 1 = Survived)', fontsize=12)
plt.show()

# %% [markdown]
# ### **Observation – Survival Rate by Passenger Title**
#
# - Passengers with the title **Mrs** had the **highest survival chance (~80%)**, meaning only ~20% died.
# - Female passengers with the title **Miss** had a **very good survival rate (~69.8%)**, with only ~30% deaths.
# - Young male passengers with the title **Master** had a **moderate survival rate (~57.5%)**, meaning ~42.5% died.
# - Passengers with **Other rare titles** had a **low survival rate (~28.6%)**, with ~71.4% deaths.
# - Male passengers with the title **Mr** faced the **highest risk**, with only ~16% survival and ~84% deaths.
#
# **Overall Trend:**
# *Women survived much more than men →*
# **Mrs > Miss > Master > Others > Mr**

# %%
df['Cabin'].value_counts().head(20)
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# C22 C26            4
# F33                4
# F2                 4
# B96 B98            4
# C78                4
# F4                 4
# D                  4
# E34                3
# B58 B60            3
# A34                3
# E101               3
# C101               3
# B51 B53 B55        3
# C31                2
# C55 C57            2
# D37                2
# C54                2
# Name: count, dtype: int64

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# np.float64(0.774637127578304)

# %%
df['Cabin'].fillna('M', inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M                  1014
# C23 C25 C27           6
# B57 B59 B63 B66       5
# G6                    5
# F33                   4
#                    ...
# A14                   1
# E63                   1
# E12                   1
# E38                   1
# C105                  1
# Name: count, Length: 187, dtype: int64

# %%
df['Deck'] = df['Cabin'].str[0]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500     M        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250     M        S          7.92500
# ...

# %%
df['Deck'].value_counts()
# Out:
# Deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
crosstab = pd.crosstab(df['Pclass'], (df['Deck'])) 
crosstab
# Out:
# Deck     A   B   C   D   E   F  G    M  T
# Pclass
# 1       22  65  94  40  34   0  0   67  1
# 2        0   0   0   6   4  13  0  254  0
# 3        0   0   0   0   3   8  5  693  0

# %%
plt.figure(figsize=(10,5))
sns.heatmap(crosstab, 
            annot=True, fmt='d', cmap='YlOrRd',
            linewidths=0.5, linecolor='white',
            cbar_kws={'label':'Passenger Count'})

plt.title('Passenger Count by Class and Deck', fontsize=14, fontweight='bold')
plt.xlabel('Deck', fontsize=12)
plt.ylabel('Pclass', fontsize=12)
plt.show()

# %% [markdown]
# ### **Observation – Deck Distribution by Passenger Class**
#
# - *1st class passengers were mostly on **Deck C (94)** and **Deck B (65)**.*
# - *2nd class passengers were highly concentrated on **Deck M (254)**.*
# - *3rd class passengers were almost entirely on **Deck M (693)**.*
#
# **Overall Trend:**
# *Lower classes were mostly on the **M (Missing/Unknown) deck**, while higher classes were on **B and C decks**.*

# %%
crosstab = pd.crosstab(df['Deck'], df['Survived'], normalize='index')
crosstab
# Out:
# Survived       0.0       1.0
# Deck
# A         0.533333  0.466667
# B         0.255319  0.744681
# C         0.406780  0.593220
# D         0.242424  0.757576
# E         0.250000  0.750000
# F         0.384615  0.615385
# G         0.500000  0.500000
# M         0.700146  0.299854
# T         1.000000  0.000000

# %%
plt.figure(figsize=(10,6))
crosstab.plot(kind='bar', stacked=True, 
              color=['#DC143C','#32CD32'],  
              edgecolor='black',
              width=0.7)

plt.title('Survival Distribution by Deck', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Deck', fontsize=12)
plt.ylabel('Passenger Count', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.legend(['Died (0)', 'Survived (1)'], title='Survival Status')
plt.show()

# %% [markdown]
# ### **Observation – Survival Rate by Deck**
#
# - *Passengers on **Deck D (~75.8%)** and **Deck E (~75%)** had the **highest survival rate**.*
# - *Passengers on **Deck B (~74.5%)** and **Deck C (~59.3%)** also had **good survival chances**.*
# - *Passengers on **Deck M (~30%)** faced the **highest risk**, as ~70% died.*
# - *Deck **T** had **0% survival**, meaning all passengers died.*
# - *Deck G and A had **moderate survival rates (~50% and ~46.7%)**.*
#
# **Overall Trend:**
# *Lower decks (like M and T) were **riskier**, while middle decks (B, D, E) were **safest**.*
